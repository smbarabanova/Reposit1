# %% [markdown]
# <a href="https://colab.research.google.com/github/smbarabanova/Reposit1/blob/main/%D0%98%D0%BD%D0%BD%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%81_%D0%B7%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print( 'Hapyness_income')

import pandas as pd
data_frame = pd.read_csv("/happyscore_income.csv")
data_frame.describe()
# Out:
# Hapyness_income
#        adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# count             111.000000        111.000000        111.000000
# mean               48.729730          5.936937          2.124595
# std                12.364131          1.356394          0.316546
# min                19.000000          2.500000          1.380000
# 25%                40.000000          5.100000          1.910000
# 50%                48.000000          6.000000          2.130000
# 75%                57.000000          7.000000          2.330000
# max                74.000000          8.500000          3.190000
#
#          avg_income  median_income  income_inequality  happyScore         GDP
# count    111.000000     111.000000         111.000000  111.000000  111.000000
# mean    6442.751416    5186.005304          38.417805    5.421910    0.841909
# std     6479.533692    5587.037239           8.375557    1.180801    0.387591
# ...

# %%
print(data_frame)
# Out:
#           country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0         Armenia                   37.0               4.9              2.42
# 1          Angola                   26.0               4.3              3.19
# 2       Argentina                   60.0               7.1              1.91
# 3         Austria                   59.0               7.2              2.11
# 4       Australia                   65.0               7.6              1.80
# ..            ...                    ...               ...               ...
# 106       Uruguay                   58.0               7.0              2.13
# 107       Vietnam                   53.0               6.1              1.77
# 108  South Africa                   49.0               6.3              2.47
# 109        Zambia                   37.0               5.0              2.61
# 110      Zimbabwe                   33.0               4.1              2.16
#
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                111 non-null    object
#  1   adjusted_satisfaction  111 non-null    float64
#  2   avg_satisfaction       111 non-null    float64
#  3   std_satisfaction       111 non-null    float64
#  4   avg_income             111 non-null    float64
#  5   median_income          111 non-null    float64
#  6   income_inequality      111 non-null    float64
#  7   region                 111 non-null    object
#  8   happyScore             111 non-null    float64
#  9   GDP                    111 non-null    float64
#  10  country.1              111 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 9.7+ KB

# %%
df1 = data_frame.isnull()
print(df1)
# Out:
#      country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0      False                  False             False             False
# 1      False                  False             False             False
# 2      False                  False             False             False
# 3      False                  False             False             False
# 4      False                  False             False             False
# ..       ...                    ...               ...               ...
# 106    False                  False             False             False
# 107    False                  False             False             False
# 108    False                  False             False             False
# 109    False                  False             False             False
# 110    False                  False             False             False
#
#      avg_income  median_income  income_inequality  region  happyScore    GDP  \
# ...

# %%
import pandas as pd
data_frame = pd.read_csv("/happyscore_income.csv")
df2 = data_frame.isnull().loc[df1["adjusted_satisfaction"] == True]
print(df2)
# Out:
# Empty DataFrame
# Columns: [country, adjusted_satisfaction, avg_satisfaction, std_satisfaction, avg_income, median_income, income_inequality, region, happyScore, GDP, country.1]
# Index: []

# %%
data_frame.corr()
# Out:
# <ipython-input-7-49d4deb62ff6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_frame.corr()
#                        adjusted_satisfaction  avg_satisfaction  \
# adjusted_satisfaction               1.000000          0.978067
# avg_satisfaction                    0.978067          1.000000
# std_satisfaction                   -0.527553         -0.341201
# avg_income                          0.728006          0.689043
# median_income                       0.704383          0.661883
# income_inequality                  -0.123835         -0.082471
# happyScore                          0.901213          0.885988
# GDP                                 0.755578          0.776679
#
#                        std_satisfaction  avg_income  median_income  \
# ...

# %%
MAX = data_frame['happyScore'].max()
print('MAX=',MAX )
# Out:
# MAX= 7.587000000000001

# %%
MIN = data_frame['happyScore'].min()
print('MIN=',MIN )
# Out:
# MIN= 2.839

# %%
MEAN = data_frame['happyScore'].mean()
print('Среднее значение=',MEAN)
# Out:
# Среднее значение= 5.421909909909912

# %%
MEDIAN = data_frame['happyScore'].median()
print('Медиана =', MEDIAN)
# Out:
# Медиана = 5.268

# %%
STD = data_frame['happyScore'].std()
print('Стандартное отклонение =', STD)
# Out:
# Стандартное отклонение = 1.180800549315818

# %%
data_frame.loc[data_frame['happyScore'] >= 5.42].sum()
# Out:
# country                  ArgentinaAustriaAustraliaBelgiumBoliviaBrazilB...
# adjusted_satisfaction                                               2988.0
# avg_satisfaction                                                     356.5
# std_satisfaction                                                     101.4
# avg_income                                                   566175.341615
# median_income                                                462548.998597
# income_inequality                                              1893.432219
# region                   'Latin America and Caribbean''Western Europe''...
# happyScore                                                         331.258
# GDP                                                               57.64733
# country.1                ArgentinaAustriaAustraliaBelgiumBoliviaBrazilB...
# dtype: object

# %%
df3 = data_frame['happyScore']>=5.42
print (df3)
df4 = df3.isnull().loc[df3['happyScore'] == True]
print (df4)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 106     True
# 107    False
# 108    False
# 109    False
# 110    False
# Name: happyScore, Length: 111, dtype: bool
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-9f395b64d02b> in <cell line: 3>()
#       1 df3 = data_frame['happyScore']>=5.42
#       2 print (df3)
# ----> 3 df4 = df3.isnull().loc[df3['happyScore'] == True]
#       4 print (df4)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
# ...
